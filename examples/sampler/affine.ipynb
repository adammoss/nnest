# %%
import os
import sys
import argparse
import logging
import torch
from torch.distributions import MultivariateNormal, Uniform, TransformedDistribution, SigmoidTransform
from getdist import plots, MCSamples
import getdist
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import collections as mc
from scipy.stats import multivariate_normal

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
path = os.path.realpath(os.path.join(os.getcwd(), '../..'))
sys.path.insert(0, path)

# %%
from nnest import NestedSampler, MCMCSampler
from nnest.trainer import Trainer
from nnest.likelihoods import *
from nnest.priors import *
from nnest.distributions import GeneralisedNormal

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
def plot_flow(samples, model):
    x_synth = model.netG.sample(samples.size).detach().cpu().numpy()
    z = model.get_latent_samples(samples)
    grid = []
    for x in np.linspace(np.min(samples[:, 0]) - 1, np.max(samples[:, 0]) + 1, 10):
        for y in np.linspace(np.min(samples[:, 1]) - 1, np.max(samples[:, 1]) + 1, 5000):
            grid.append([x, y])
    for y in np.linspace(np.min(samples[:, 1]) - 1, np.max(samples[:, 1]) + 1, 10):
        for x in np.linspace(np.min(samples[:, 0]) - 1, np.max(samples[:, 0]) + 1, 5000):
            grid.append([x, y])
    grid = np.array(grid)
    z_grid = model.get_latent_samples(grid)
    fig, ax = plt.subplots(1, 3, figsize=(12, 5))
    ax[0].scatter(grid[:, 0], grid[:, 1], c=grid[:, 0], marker='.', s=1, linewidths=0)
    ax[0].scatter(samples[:, 0], samples[:, 1], s=4)
    ax[0].set_title('Real data')
    ax[1].scatter(z_grid[:, 0], z_grid[:, 1], c=grid[:, 0], marker='.', s=1, linewidths=0)
    ax[1].scatter(z[:, 0], z[:, 1], s=4)
    ax[1].set_title('Latent data')
    ax[2].scatter(x_synth[:, 0], x_synth[:, 1], s=2)
    ax[2].set_title('Synthetic data')
    plt.tight_layout()
    plt.show()
    # Plot grid warp
    plt.figure(figsize=(6,6))
    ng = 30
    xx, yy = np.linspace(-4,4, ng), np.linspace(-4,4, ng)
    xv, yv = np.meshgrid(xx, yy)
    xy = np.stack([xv, yv], axis=-1)
    in_circle = np.sqrt((xy**2).sum(axis=2)) <= 3
    xy = xy.reshape((ng*ng, 2))
    xy = torch.from_numpy(xy.astype(np.float32))
    xs = model.get_samples(xy)
    xs = xs.reshape((ng, ng, 2))
    p1 = np.reshape(xs[1:,:,:], (ng**2-ng,2))
    p2 = np.reshape(xs[:-1,:,:], (ng**2-ng,2))
    inc = np.reshape(in_circle[1:,:] | in_circle[:-1,:], (ng**2-ng,))
    p1, p2 = p1[inc], p2[inc]
    lcy = mc.LineCollection(zip(p1, p2), linewidths=1, alpha=0.5, color='k')
    p1 = np.reshape(xs[:,1:,:], (ng**2-ng,2))
    p2 = np.reshape(xs[:,:-1,:], (ng**2-ng,2))
    inc = np.reshape(in_circle[:,1:] | in_circle[:,:-1], (ng**2-ng,))
    p1, p2 = p1[inc], p2[inc]
    lcx = mc.LineCollection(zip(p1, p2), linewidths=1, alpha=0.5, color='k')
    plt.gca().add_collection(lcy)
    plt.gca().add_collection(lcx)
    plt.xlim([np.min(samples[:,0])-0.05,np.max(samples[:,0])+0.05])
    plt.ylim([np.min(samples[:,1])-0.05,np.max(samples[:,1])+0.05])
    plt.scatter(samples[:,0], samples[:,1], c='r', s=5, alpha=0.5)
    plt.show()

# %%
def test_mcmc(like, prior, model, nwalkers=40, init_chain=True, nested_samples=True, mcmc_steps=100, nested_fraction=0.01):
    np.random.seed(0)
    if nested_samples:
        init_samples, loglstar = like.uniform_sample(prior, 1000, nested_fraction)
    else:
        init_samples = like.sample(prior, 1000)
        loglstar = None
    model.train(init_samples, jitter=0.01, max_iters=2000)
    plot_flow(init_samples, model)
    sampler = MCMCSampler(like.x_dim, like, prior=prior, trainer=model, log_level=logging.INFO)
    if init_chain:
        results = sampler._emcee_sample(mcmc_steps, nwalkers, init_state=init_samples[0:nwalkers, :], 
                                       loglstar=loglstar, stats_interval=1)
    else:
        results = sampler._emcee_sample(mcmc_steps, nwalkers, loglstar=loglstar, stats_interval=1)
    samples, latent_samples, derived_samples, loglikes, ncall, state = results
    fig, ax = plt.subplots(1, 2, figsize=(12,6))
    flat_samples = samples.reshape((-1, like.x_dim))
    flat_latent_samples = latent_samples.reshape((-1, like.x_dim))
    ax[0].scatter(flat_samples[:,0], flat_samples[:,1], c='r', s=5, alpha=0.5)
    ax[1].scatter(flat_latent_samples[:,0], flat_latent_samples[:,1], c='r', s=5, alpha=0.5)
    plt.show()
    fig, ax = plt.subplots(like.x_dim, 2, figsize=(10, like.x_dim))
    for i in range(like.x_dim):
        ax[i, 0].plot(samples[0,0:1000,i])
        ax[i, 1].plot(latent_samples[0,0:1000,i])
    plt.show()
    mc = MCSamples(samples=[samples[i, :, :].squeeze() for i in range(samples.shape[0])], 
                   loglikes=[-loglikes[i, :].squeeze() for i in range(loglikes.shape[0])])
    try:
        print(mc.getEffectiveSamples())
    except:
        pass
    try:
        print(mc.getConvergeTests())
    except: 
        pass
    print(ncall)

# %%
nwalkers = 100

# %%
prior = UniformPrior(2, -15, 15)
like = Eggbox(2)

# %%
model = Trainer(like.x_dim, flow='spline', learning_rate=0.001)
test_mcmc(like, prior, model, init_chain=False, nwalkers=nwalkers, nested_samples=False)
# Out:
# [nnest.trainer] [INFO] SingleSpeedSpline(
#   (flow): NormalizingFlow(
#     (flows): ModuleList(
#       (0): ActNorm()
#       (1): Invertible1x1Conv()
#       (2): NSF_CL(
#         (f1): MLP(
#           (net): Sequential(
#             (0): Linear(in_features=1, out_features=16, bias=True)
#             (1): LeakyReLU(negative_slope=0.2)
#             (2): Linear(in_features=16, out_features=16, bias=True)
#             (3): LeakyReLU(negative_slope=0.2)
#             (4): Linear(in_features=16, out_features=16, bias=True)
#             (5): LeakyReLU(negative_slope=0.2)
#             (6): Linear(in_features=16, out_features=23, bias=True)
#           )
#         )
#         (f2): MLP(
#           (net): Sequential(
#             (0): Linear(in_features=1, out_features=16, bias=True)
#             (1): LeakyReLU(negative_slope=0.2)
#             (2): Linear(in_features=16, out_features=16, bias=True)
#             (3): LeakyReLU(negative_slope=0.2)
#             (4): Linear(in_features=16, out_features=16, bias=True)
#             (5): LeakyReLU(negative_slope=0.2)
#             (6): Linear(in_features=16, out_features=23, bias=True)
#           )
#         )
#       )
#       (3): ActNorm()
#       (4): Invertible1x1Conv()
#       (5): NSF_CL(
#         (f1): MLP(
#           (net): Sequential(
#             (0): Linear(in_features=1, out_features=16, bias=True)
#             (1): LeakyReLU(negative_slope=0.2)
#             (2): Linear(in_features=16, out_features=16, bias=True)
#             (3): LeakyReLU(negative_slope=0.2)
#             (4): Linear(in_features=16, out_features=16, bias=True)
#             (5): LeakyReLU(negative_slope=0.2)
#             (6): Linear(in_features=16, out_features=23, bias=True)
#           )
#         )
#         (f2): MLP(
#           (net): Sequential(
#             (0): Linear(in_features=1, out_features=16, bias=True)
#             (1): LeakyReLU(negative_slope=0.2)
#             (2): Linear(in_features=16, out_features=16, bias=True)
#             (3): LeakyReLU(negative_slope=0.2)
#             (4): Linear(in_features=16, out_features=16, bias=True)
#             (5): LeakyReLU(negative_slope=0.2)
#             (6): Linear(in_features=16, out_features=23, bias=True)
#           )
#         )
#       )
#       (6): ActNorm()
#       (7): Invertible1x1Conv()
#       (8): NSF_CL(
#         (f1): MLP(
#           (net): Sequential(
#             (0): Linear(in_features=1, out_features=16, bias=True)
#             (1): LeakyReLU(negative_slope=0.2)
#             (2): Linear(in_features=16, out_features=16, bias=True)
#             (3): LeakyReLU(negative_slope=0.2)
#             (4): Linear(in_features=16, out_features=16, bias=True)
#             (5): LeakyReLU(negative_slope=0.2)
#             (6): Linear(in_features=16, out_features=23, bias=True)
#           )
#         )
#         (f2): MLP(
#           (net): Sequential(
#             (0): Linear(in_features=1, out_features=16, bias=True)
#             (1): LeakyReLU(negative_slope=0.2)
#             (2): Linear(in_features=16, out_features=16, bias=True)
#             (3): LeakyReLU(negative_slope=0.2)
#             (4): Linear(in_features=16, out_features=16, bias=True)
#             (5): LeakyReLU(negative_slope=0.2)
#             (6): Linear(in_features=16, out_features=23, bias=True)
#           )
#         )
#       )
#     )
#   )
# )
# [nnest.trainer] [INFO] Number of network params: [5844]
# [nnest.trainer] [INFO] Device [cpu]
# [nnest.trainer] [INFO] Number of training samples [1000]
# [nnest.trainer] [INFO] Training jitter [0.0100]
# [nnest.trainer] [INFO] Epoch [1] train loss [0.0740] validation loss [0.0728]
# [nnest.trainer] [INFO] Epoch [100] train loss [0.0153] validation loss [0.0133]
# [nnest.trainer] [INFO] Epoch [152] ran out of patience
# [nnest.trainer] [INFO] Best epoch [102] validation loss [0.0125]
# Creating directory for new run logs/test/run82
# [nnest.sampler] [INFO] Num base params [2]
# [nnest.sampler] [INFO] Num derived params [0]
# [nnest.sampler] [INFO] Total params [2]
# /Users/adammoss/opt/anaconda3/envs/nnest/lib/python3.8/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in double_scalars
#   lnpdiff = f + nlp - state.log_prob[j]
# [nnest.sampler] [INFO] Step [1]  acceptance [0.5600]
# [nnest.sampler] [INFO] Step [2]  acceptance [0.5350]
# [nnest.sampler] [INFO] Step [3]  acceptance [0.5333]
# [nnest.sampler] [INFO] Step [4]  acceptance [0.5250]
# [nnest.sampler] [INFO] Step [5]  acceptance [0.5220]
# [nnest.sampler] [INFO] Step [6]  acceptance [0.5083]
# [nnest.sampler] [INFO] Step [7]  acceptance [0.5029]
# [nnest.sampler] [INFO] Step [8]  acceptance [0.4963]
# [nnest.sampler] [INFO] Step [9]  acceptance [0.4878]
# [nnest.sampler] [INFO] Step [10]  acceptance [0.4920]
# [nnest.sampler] [INFO] Step [11]  acceptance [0.4891]
# [nnest.sampler] [INFO] Step [12]  acceptance [0.4850]
# [nnest.sampler] [INFO] Step [13]  acceptance [0.4808]
# [nnest.sampler] [INFO] Step [14]  acceptance [0.4836]
# [nnest.sampler] [INFO] Step [15]  acceptance [0.4853]
# [nnest.sampler] [INFO] Step [16]  acceptance [0.4856]
# [nnest.sampler] [INFO] Step [17]  acceptance [0.4747]
# [nnest.sampler] [INFO] Step [18]  acceptance [0.4706]
# [nnest.sampler] [INFO] Step [19]  acceptance [0.4668]
# [nnest.sampler] [INFO] Step [20]  acceptance [0.4650]
# [nnest.sampler] [INFO] Step [21]  acceptance [0.4629]
# [nnest.sampler] [INFO] Step [22]  acceptance [0.4632]
# [nnest.sampler] [INFO] Step [23]  acceptance [0.4596]
# [nnest.sampler] [INFO] Step [24]  acceptance [0.4562]
# [nnest.sampler] [INFO] Step [25]  acceptance [0.4560]
# [nnest.sampler] [INFO] Step [26]  acceptance [0.4596]
# [nnest.sampler] [INFO] Step [27]  acceptance [0.4596]
# [nnest.sampler] [INFO] Step [28]  acceptance [0.4593]
# [nnest.sampler] [INFO] Step [29]  acceptance [0.4552]
# [nnest.sampler] [INFO] Step [30]  acceptance [0.4570]
# [nnest.sampler] [INFO] Step [31]  acceptance [0.4584]
# [nnest.sampler] [INFO] Step [32]  acceptance [0.4550]
# [nnest.sampler] [INFO] Step [33]  acceptance [0.4552]
# [nnest.sampler] [INFO] Step [34]  acceptance [0.4568]
# [nnest.sampler] [INFO] Step [35]  acceptance [0.4551]
# [nnest.sampler] [INFO] Step [36]  acceptance [0.4522]
# [nnest.sampler] [INFO] Step [37]  acceptance [0.4524]
# [nnest.sampler] [INFO] Step [38]  acceptance [0.4511]
# [nnest.sampler] [INFO] Step [39]  acceptance [0.4487]
# [nnest.sampler] [INFO] Step [40]  acceptance [0.4490]
# [nnest.sampler] [INFO] Step [41]  acceptance [0.4490]
# [nnest.sampler] [INFO] Step [42]  acceptance [0.4488]
# [nnest.sampler] [INFO] Step [43]  acceptance [0.4470]
# [nnest.sampler] [INFO] Step [44]  acceptance [0.4466]
# [nnest.sampler] [INFO] Step [45]  acceptance [0.4464]
# [nnest.sampler] [INFO] Step [46]  acceptance [0.4467]
# [nnest.sampler] [INFO] Step [47]  acceptance [0.4472]
# [nnest.sampler] [INFO] Step [48]  acceptance [0.4488]
# [nnest.sampler] [INFO] Step [49]  acceptance [0.4476]
# [nnest.sampler] [INFO] Step [50]  acceptance [0.4462]
# [nnest.sampler] [INFO] Step [51]  acceptance [0.4459]
# [nnest.sampler] [INFO] Step [52]  acceptance [0.4437]
# [nnest.sampler] [INFO] Step [53]  acceptance [0.4440]
# [nnest.sampler] [INFO] Step [54]  acceptance [0.4444]
# [nnest.sampler] [INFO] Step [55]  acceptance [0.4436]
# [nnest.sampler] [INFO] Step [56]  acceptance [0.4436]
# [nnest.sampler] [INFO] Step [57]  acceptance [0.4430]
# [nnest.sampler] [INFO] Step [58]  acceptance [0.4428]
# [nnest.sampler] [INFO] Step [59]  acceptance [0.4432]
# [nnest.sampler] [INFO] Step [60]  acceptance [0.4428]
# [nnest.sampler] [INFO] Step [61]  acceptance [0.4428]
# [nnest.sampler] [INFO] Step [62]  acceptance [0.4424]
# [nnest.sampler] [INFO] Step [63]  acceptance [0.4438]
# [nnest.sampler] [INFO] Step [64]  acceptance [0.4423]
# [nnest.sampler] [INFO] Step [65]  acceptance [0.4422]
# [nnest.sampler] [INFO] Step [66]  acceptance [0.4426]
# [nnest.sampler] [INFO] Step [67]  acceptance [0.4424]
# [nnest.sampler] [INFO] Step [68]  acceptance [0.4403]
# [nnest.sampler] [INFO] Step [69]  acceptance [0.4391]
# [nnest.sampler] [INFO] Step [70]  acceptance [0.4383]
# [nnest.sampler] [INFO] Step [71]  acceptance [0.4380]
# [nnest.sampler] [INFO] Step [72]  acceptance [0.4371]
# [nnest.sampler] [INFO] Step [73]  acceptance [0.4358]
# [nnest.sampler] [INFO] Step [74]  acceptance [0.4361]
# [nnest.sampler] [INFO] Step [75]  acceptance [0.4377]
# [nnest.sampler] [INFO] Step [76]  acceptance [0.4380]
# [nnest.sampler] [INFO] Step [77]  acceptance [0.4381]
# [nnest.sampler] [INFO] Step [78]  acceptance [0.4387]
# [nnest.sampler] [INFO] Step [79]  acceptance [0.4385]
# [nnest.sampler] [INFO] Step [80]  acceptance [0.4387]
# [nnest.sampler] [INFO] Step [81]  acceptance [0.4393]
# [nnest.sampler] [INFO] Step [82]  acceptance [0.4388]
# [nnest.sampler] [INFO] Step [83]  acceptance [0.4390]
# [nnest.sampler] [INFO] Step [84]  acceptance [0.4388]
# [nnest.sampler] [INFO] Step [85]  acceptance [0.4381]
# [nnest.sampler] [INFO] Step [86]  acceptance [0.4376]
# [nnest.sampler] [INFO] Step [87]  acceptance [0.4372]
# [nnest.sampler] [INFO] Step [88]  acceptance [0.4373]
# [nnest.sampler] [INFO] Step [89]  acceptance [0.4363]
# [nnest.sampler] [INFO] Step [90]  acceptance [0.4360]
# [nnest.sampler] [INFO] Step [91]  acceptance [0.4360]
# [nnest.sampler] [INFO] Step [92]  acceptance [0.4359]
# [nnest.sampler] [INFO] Step [93]  acceptance [0.4355]
# [nnest.sampler] [INFO] Step [94]  acceptance [0.4357]
# [nnest.sampler] [INFO] Step [95]  acceptance [0.4353]
# [nnest.sampler] [INFO] Step [96]  acceptance [0.4347]
# [nnest.sampler] [INFO] Step [97]  acceptance [0.4347]
# [nnest.sampler] [INFO] Step [98]  acceptance [0.4347]
# [nnest.sampler] [INFO] Step [99]  acceptance [0.4354]
# [nnest.sampler] [INFO] Step [100]  acceptance [0.4350]
# Removed no burn in
# 517.1857953565781
# Parameter autocorrelation lengths (effective number of samples N_eff = tot weight/weight length)
#
#             Weight Length   Sample length           N_eff
# param1           7.80E-01            0.78           12821
# param2           6.25E-01            0.63           15999
#
#
# mean convergence stats using remaining chains
# param sqrt(var(chain mean)/mean(chain var))
#
# param1        0.5338  p_{1}
# param2        0.7784  p_{2}
#
# var(mean)/mean(var) for eigenvalues of covariance of y of orthonormalized parameters
#   1      0.28497
#   2      0.60599
#
# Split tests: rms_n([delta(upper/lower quantile)]/sd) n={2,3,4}, limit=95%:
# i.e. mean sample splitting change in the quantiles in units of the st. dev.
#
# param1       0.0005   0.0023   0.0016 upper
# param1       0.0012   0.0016   0.0036 lower
# param2       0.0003   0.0010   0.0008 upper
# param2       0.0013   0.0005   0.0014 lower
#
# Raftery&Lewis statistics
#
# chain  markov_thin  indep_thin    nburn
#    0      Failed/not enough samples
#    1           1           1          17
#    2           1           3          17
#    3      Failed/not enough samples
#    4           1           2          23
#    5      Failed/not enough samples
#    6           1           1          10
#    7      Failed/not enough samples
#    8      Failed/not enough samples
#    9      Failed/not enough samples
#   10      Failed/not enough samples
#   11      Failed/not enough samples
#   12      Failed/not enough samples
#   13      Failed/not enough samples
#   14      Failed/not enough samples
#   15      Failed/not enough samples
#   16           1           1          17
#   17           1           3          13
#   18      Failed/not enough samples
#   19      Failed/not enough samples
#   20           1           1          17
#   21           1           6          17
#   22      Failed/not enough samples
#   23           1           1          17
#   24           1           1          10
#   25      Failed/not enough samples
#   26      Failed/not enough samples
#   27           1           2          10
#   28      Failed/not enough samples
#   29      Failed/not enough samples
#   30      Failed/not enough samples
#   31      Failed/not enough samples
#   32           1           1          29
#   33      Failed/not enough samples
#   34      Failed/not enough samples
#   35      Failed/not enough samples
#   36      Failed/not enough samples
#   37      Failed/not enough samples
#   38      Failed/not enough samples
#   39      Failed/not enough samples
#   40      Failed/not enough samples
#   41      Failed/not enough samples
#   42           1           1          43
#   43           1           2          10
#   44           1           2          17
#   45      Failed/not enough samples
#   46      Failed/not enough samples
#   47           1           1          17
#   48      Failed/not enough samples
#   49           1           2          10
#   50      Failed/not enough samples
#   51           1           1          23
#   52      Failed/not enough samples
#   53      Failed/not enough samples
#   54           1           1          17
#   55      Failed/not enough samples
#   56      Failed/not enough samples
#   57      Failed/not enough samples
#   58      Failed/not enough samples
#   59           1           1          17
#   60           1           3          23
#   61      Failed/not enough samples
#   62      Failed/not enough samples
#   63      Failed/not enough samples
#   64      Failed/not enough samples
#   65           1           4          17
#   66      Failed/not enough samples
#   67      Failed/not enough samples
#   68           1           1          17
#   69      Failed/not enough samples
#   70      Failed/not enough samples
#   71           1           1          17
#   72           1           2          13
#   73      Failed/not enough samples
#   74      Failed/not enough samples
#   75      Failed/not enough samples
#   76           1           1          29
#   77      Failed/not enough samples
#   78      Failed/not enough samples
#   79      Failed/not enough samples
#   80      Failed/not enough samples
#   81           1           1          23
#   82           1           5          25
#   83      Failed/not enough samples
#   84           1           3          17
#   85      Failed/not enough samples
#   86      Failed/not enough samples
#   87           1           1          23
#   88           1           2          53
#   89      Failed/not enough samples
#   90      Failed/not enough samples
#   91      Failed/not enough samples
#   92      Failed/not enough samples
#   93      Failed/not enough samples
#   94      Failed/not enough samples
#   95      Failed/not enough samples
#   96      Failed/not enough samples
#   97      Failed/not enough samples
#   98           1           3          10
#   99      Failed/not enough samples
#
#
# 10000
