# %% [markdown]
# Example notebook showing how to use the nested sampler

# %%
import os
import sys
import argparse
import torch
from getdist import plots, MCSamples
import getdist
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import multivariate_normal
import logging

# %%
#logging.disable(logging.INFO)

# %%
path = os.path.realpath(os.path.join(os.getcwd(), '../..'))
sys.path.insert(0, path)

# %%
from nnest import NestedSampler, MCMCSampler
from nnest.likelihoods import *
from nnest.priors import *

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
# Likelihood + prior
like = Himmelblau(2)
transform = lambda x: 5*x
prior = UniformPrior(2, -5, 5)
#like = Rosenbrock(2)
#transform = lambda x: 5*x
#prior = UniformPrior(2, -2, 5)
#prior = UniformPrior(4, -2, 5)
#like = Gaussian(2, 0.9)
#transform = lambda x: 3*x
#like = Eggbox(2)
#transform = lambda x: 5*np.pi*x
#like = GaussianShell(2)
#transform = lambda x: 3*x
#prior = UniformPrior(2, -3, 3)
#like = GaussianMix(2)
#transform = lambda x: 5*x

# %%
sampler = MCMCSampler(like.x_dim, like, hidden_dim=16, num_blocks=3, flow='spline', prior=prior, run_num=1)
# Out:
# [nnest.trainer] [INFO] SingleSpeedSpline(
#   (flow): NormalizingFlow(
#     (flows): ModuleList(
#       (0): ActNorm()
#       (1): Invertible1x1Conv()
#       (2): NSF_CL(
#         (f1): MLP(
#           (net): Sequential(
#             (0): Linear(in_features=1, out_features=16, bias=True)
#             (1): LeakyReLU(negative_slope=0.2)
#             (2): Linear(in_features=16, out_features=16, bias=True)
#             (3): LeakyReLU(negative_slope=0.2)
#             (4): Linear(in_features=16, out_features=16, bias=True)
#             (5): LeakyReLU(negative_slope=0.2)
#             (6): Linear(in_features=16, out_features=23, bias=True)
#           )
#         )
#         (f2): MLP(
#           (net): Sequential(
#             (0): Linear(in_features=1, out_features=16, bias=True)
#             (1): LeakyReLU(negative_slope=0.2)
#             (2): Linear(in_features=16, out_features=16, bias=True)
#             (3): LeakyReLU(negative_slope=0.2)
#             (4): Linear(in_features=16, out_features=16, bias=True)
#             (5): LeakyReLU(negative_slope=0.2)
#             (6): Linear(in_features=16, out_features=23, bias=True)
#           )
#         )
#       )
#       (3): ActNorm()
#       (4): Invertible1x1Conv()
#       (5): NSF_CL(
#         (f1): MLP(
#           (net): Sequential(
#             (0): Linear(in_features=1, out_features=16, bias=True)
#             (1): LeakyReLU(negative_slope=0.2)
#             (2): Linear(in_features=16, out_features=16, bias=True)
#             (3): LeakyReLU(negative_slope=0.2)
#             (4): Linear(in_features=16, out_features=16, bias=True)
#             (5): LeakyReLU(negative_slope=0.2)
#             (6): Linear(in_features=16, out_features=23, bias=True)
#           )
#         )
#         (f2): MLP(
#           (net): Sequential(
#             (0): Linear(in_features=1, out_features=16, bias=True)
#             (1): LeakyReLU(negative_slope=0.2)
#             (2): Linear(in_features=16, out_features=16, bias=True)
#             (3): LeakyReLU(negative_slope=0.2)
#             (4): Linear(in_features=16, out_features=16, bias=True)
#             (5): LeakyReLU(negative_slope=0.2)
#             (6): Linear(in_features=16, out_features=23, bias=True)
#           )
#         )
#       )
#       (6): ActNorm()
#       (7): Invertible1x1Conv()
#       (8): NSF_CL(
#         (f1): MLP(
#           (net): Sequential(
#             (0): Linear(in_features=1, out_features=16, bias=True)
#             (1): LeakyReLU(negative_slope=0.2)
#             (2): Linear(in_features=16, out_features=16, bias=True)
#             (3): LeakyReLU(negative_slope=0.2)
#             (4): Linear(in_features=16, out_features=16, bias=True)
#             (5): LeakyReLU(negative_slope=0.2)
#             (6): Linear(in_features=16, out_features=23, bias=True)
#           )
#         )
#         (f2): MLP(
#           (net): Sequential(
#             (0): Linear(in_features=1, out_features=16, bias=True)
#             (1): LeakyReLU(negative_slope=0.2)
#             (2): Linear(in_features=16, out_features=16, bias=True)
#             (3): LeakyReLU(negative_slope=0.2)
#             (4): Linear(in_features=16, out_features=16, bias=True)
#             (5): LeakyReLU(negative_slope=0.2)
#             (6): Linear(in_features=16, out_features=23, bias=True)
#           )
#         )
#       )
#     )
#   )
# )
# [nnest.trainer] [INFO] Number of network params: [5844]
# [nnest.trainer] [INFO] Device [cpu]
# [nnest.sampler] [INFO] Num base params [2]
# [nnest.sampler] [INFO] Num derived params [0]
# [nnest.sampler] [INFO] Total params [2]

# %%
sampler.run(bootstrap_iters=0)
# Out:
# [nnest.sampler] [INFO] Alpha [0.7071]
# Creating directory for new run logs/test/run23
# [nnest.sampler] [INFO] Num base params [2]
# [nnest.sampler] [INFO] Num derived params [0]
# [nnest.sampler] [INFO] Total params [2]
# [nnest.sampler] [INFO] Num live points [100]
# [nnest.sampler] [INFO] MCMC steps [4]
# [nnest.sampler] [INFO] Initial scale [1.4142]
# [nnest.sampler] [INFO] Volume switch [-1.0000]
# [nnest.sampler] [INFO] Step [0] loglstar [-2.2943e+02] max logl [-1.7398e-01] logz [-2.3404e+02] vol [1.00000e+00] ncalls [101] mean calls [0.0000]
# [nnest.sampler] [INFO] Step [20] loglstar [-5.9388e+01] max logl [-1.0507e-01] logz [-6.3845e+01] vol [8.18731e-01] ncalls [124] mean calls [1.2000]
# [nnest.sampler] [INFO] Step [40] loglstar [-3.5648e+01] max logl [-2.9148e-02] logz [-4.0158e+01] vol [6.70320e-01] ncalls [158] mean calls [1.6000]
# [nnest.sampler] [INFO] Step [60] loglstar [-2.7645e+01] max logl [-2.3607e-03] logz [-3.1815e+01] vol [5.48812e-01] ncalls [193] mean calls [1.7000]
# [nnest.sampler] [INFO] Step [80] loglstar [-2.0755e+01] max logl [-2.9799e-04] logz [-2.5039e+01] vol [4.49329e-01] ncalls [240] mean calls [3.0000]
# [nnest.sampler] [INFO] Step [100] loglstar [-1.4366e+01] max logl [-4.8240e-07] logz [-1.8472e+01] vol [3.67879e-01] ncalls [275] mean calls [1.3000]
# [nnest.sampler] [INFO] Step [120] loglstar [-9.8612e+00] max logl [-4.8240e-07] logz [-1.3992e+01] vol [3.01194e-01] ncalls [341] mean calls [3.3000]
# [nnest.sampler] [INFO] Step [140] loglstar [-6.8152e+00] max logl [-4.8240e-07] logz [-1.0853e+01] vol [2.46597e-01] ncalls [405] mean calls [2.9000]
# [nnest.sampler] [INFO] Rejection prior no longer efficient
# [nnest.trainer] [INFO] Number of training samples [100]
# [nnest.trainer] [INFO] Training jitter [0.0056]
# [nnest.trainer] [INFO] Epoch [1] train loss [0.0163] validation loss [0.1377]
# [nnest.trainer] [INFO] Epoch [50] train loss [0.0139] validation loss [0.1260]
# [nnest.trainer] [INFO] Epoch [100] train loss [0.0121] validation loss [0.1143]
# [nnest.trainer] [INFO] Epoch [150] train loss [0.0103] validation loss [0.1054]
# [nnest.trainer] [INFO] Epoch [200] train loss [0.0085] validation loss [0.0961]
# [nnest.trainer] [INFO] Epoch [250] train loss [0.0066] validation loss [0.0861]
# [nnest.trainer] [INFO] Epoch [300] train loss [0.0045] validation loss [0.0798]
# [nnest.trainer] [INFO] Epoch [350] train loss [0.0028] validation loss [0.0734]
# [nnest.trainer] [INFO] Epoch [400] train loss [0.0013] validation loss [0.0657]
# [nnest.trainer] [INFO] Epoch [450] train loss [0.0001] validation loss [0.0632]
# [nnest.trainer] [INFO] Epoch [500] train loss [-0.0009] validation loss [0.0596]
# [nnest.trainer] [INFO] Best epoch [500] validation loss [0.0596]
# [nnest.sampler] [INFO] Acceptance [0.5000] min ESS [1.5668] max ESS [2.5076] average jump [0.1594]
# [nnest.sampler] [INFO] Step [160] loglstar [-4.9176e+00] maxlogl [-4.8240e-07] logz [-8.4698e+00] vol [2.01897e-01] ncalls [494] scale [0.1914]
# [nnest.sampler] [INFO] Acceptance [0.4250] min ESS [1.7508] max ESS [2.6327] average jump [0.1495]
# [nnest.sampler] [INFO] Step [180] loglstar [-3.5747e+00] maxlogl [-4.8240e-07] logz [-7.1624e+00] vol [1.65299e-01] ncalls [547] scale [0.1620]
# [nnest.trainer] [INFO] Number of training samples [100]
# [nnest.trainer] [INFO] Training jitter [0.0041]
# [nnest.trainer] [INFO] Epoch [1] train loss [-0.0013] validation loss [-0.0343]
# [nnest.trainer] [INFO] Epoch [50] train loss [-0.0036] validation loss [-0.0468]
# [nnest.trainer] [INFO] Epoch [100] train loss [-0.0044] validation loss [-0.0562]
# [nnest.trainer] [INFO] Epoch [150] train loss [-0.0055] validation loss [-0.0571]
# [nnest.trainer] [INFO] Epoch [200] train loss [-0.0059] validation loss [-0.0645]
# [nnest.trainer] [INFO] Epoch [250] train loss [-0.0065] validation loss [-0.0767]
# [nnest.trainer] [INFO] Epoch [300] train loss [-0.0073] validation loss [-0.0779]
# [nnest.trainer] [INFO] Epoch [350] train loss [-0.0075] validation loss [-0.0843]
# [nnest.trainer] [INFO] Epoch [400] train loss [-0.0079] validation loss [-0.0833]
# [nnest.trainer] [INFO] Epoch [405] ran out of patience
# [nnest.trainer] [INFO] Best epoch [355] validation loss [-0.0902]
# [nnest.sampler] [INFO] Acceptance [0.4500] min ESS [1.6204] max ESS [1.8445] average jump [0.1161]
# [nnest.sampler] [INFO] Step [200] loglstar [-2.4114e+00] maxlogl [-4.8240e-07] logz [-5.9715e+00] vol [1.35335e-01] ncalls [603] scale [0.1620]
# [nnest.sampler] [INFO] Acceptance [0.2000] min ESS [2.0593] max ESS [2.2420] average jump [0.1463]
# [nnest.sampler] [INFO] Step [220] loglstar [-1.5548e+00] maxlogl [-4.8240e-07] logz [-5.1271e+00] vol [1.10803e-01] ncalls [648] scale [1.6707]
# [nnest.sampler] [INFO] Acceptance [0.4750] min ESS [2.3644] max ESS [2.5921] average jump [0.1993]
# [nnest.sampler] [INFO] Step [240] loglstar [-1.0264e+00] maxlogl [-4.8240e-07] logz [-4.4519e+00] vol [9.07180e-02] ncalls [701] scale [0.8578]
# [nnest.sampler] [INFO] Acceptance [0.3750] min ESS [1.9798] max ESS [2.0482] average jump [0.1195]
# [nnest.sampler] [INFO] Step [260] loglstar [-6.9204e-01] maxlogl [-4.8240e-07] logz [-3.9645e+00] vol [7.42736e-02] ncalls [778] scale [0.2261]
# [nnest.sampler] [INFO] Acceptance [0.4750] min ESS [1.5266] max ESS [1.7743] average jump [0.0878]
# [nnest.sampler] [INFO] Step [280] loglstar [-4.3074e-01] maxlogl [-4.8240e-07] logz [-3.6167e+00] vol [6.08101e-02] ncalls [832] scale [0.1914]
# [nnest.trainer] [INFO] Number of training samples [100]
# [nnest.trainer] [INFO] Training jitter [0.0027]
# [nnest.trainer] [INFO] Epoch [1] train loss [-0.0069] validation loss [-0.0434]
# [nnest.trainer] [INFO] Epoch [50] train loss [-0.0137] validation loss [-0.0838]
# [nnest.trainer] [INFO] Epoch [100] train loss [-0.0152] validation loss [-0.0980]
# [nnest.trainer] [INFO] Epoch [150] train loss [-0.0171] validation loss [-0.1053]
# [nnest.trainer] [INFO] Epoch [200] train loss [-0.0179] validation loss [-0.1090]
# [nnest.trainer] [INFO] Epoch [250] train loss [-0.0184] validation loss [-0.1149]
# [nnest.trainer] [INFO] Epoch [300] train loss [-0.0192] validation loss [-0.1044]
# [nnest.trainer] [INFO] Epoch [323] ran out of patience
# [nnest.trainer] [INFO] Best epoch [273] validation loss [-0.1269]
# [nnest.sampler] [INFO] Acceptance [0.5500] min ESS [2.1635] max ESS [2.3029] average jump [0.1931]
# [nnest.sampler] [INFO] Step [300] loglstar [-2.7125e-01] maxlogl [-4.8240e-07] logz [-3.3652e+00] vol [4.97871e-02] ncalls [913] scale [0.8578]
# [nnest.sampler] [INFO] Acceptance [0.4750] min ESS [1.4184] max ESS [2.6362] average jump [0.0893]
# [nnest.sampler] [INFO] Step [320] loglstar [-1.7728e-01] maxlogl [-4.8240e-07] logz [-3.1771e+00] vol [4.07622e-02] ncalls [966] scale [0.3156]
# [nnest.sampler] [INFO] Acceptance [0.4750] min ESS [1.8975] max ESS [2.1736] average jump [0.1355]
# [nnest.sampler] [INFO] Step [340] loglstar [-1.0150e-01] maxlogl [-4.8240e-07] logz [-3.0345e+00] vol [3.33733e-02] ncalls [1041] scale [0.1620]
# [nnest.sampler] [INFO] niter: 346
#  ncall: 1041
#  nsamples: 446
#  logz: -2.523 +/-  0.143
#  h:  2.050
# WARNING:root:outlier fraction 0.11342592592592593
# Removed no burn in
# [nnest.trainer] [INFO] Number of training samples [201]
# INFO:nnest.trainer:Number of training samples [201]
# [nnest.trainer] [INFO] Training jitter [0.0100]
# INFO:nnest.trainer:Training jitter [0.0100]
# [nnest.trainer] [INFO] Epoch [1] train loss [0.1455] validation loss [0.6312]
# INFO:nnest.trainer:Epoch [1] train loss [0.1455] validation loss [0.6312]
# [nnest.trainer] [INFO] Epoch [50] train loss [0.0700] validation loss [0.3088]
# INFO:nnest.trainer:Epoch [50] train loss [0.0700] validation loss [0.3088]
# [nnest.trainer] [INFO] Epoch [100] train loss [0.0321] validation loss [0.1310]
# INFO:nnest.trainer:Epoch [100] train loss [0.0321] validation loss [0.1310]
# [nnest.trainer] [INFO] Epoch [150] train loss [0.0160] validation loss [0.0986]
# INFO:nnest.trainer:Epoch [150] train loss [0.0160] validation loss [0.0986]
# [nnest.trainer] [INFO] Epoch [200] train loss [0.0141] validation loss [0.0905]
# INFO:nnest.trainer:Epoch [200] train loss [0.0141] validation loss [0.0905]
# [nnest.trainer] [INFO] Epoch [250] train loss [0.0129] validation loss [0.0869]
# INFO:nnest.trainer:Epoch [250] train loss [0.0129] validation loss [0.0869]
# [nnest.trainer] [INFO] Epoch [300] train loss [0.0125] validation loss [0.0824]
# INFO:nnest.trainer:Epoch [300] train loss [0.0125] validation loss [0.0824]
# [nnest.trainer] [INFO] Epoch [350] train loss [0.0118] validation loss [0.0767]
# INFO:nnest.trainer:Epoch [350] train loss [0.0118] validation loss [0.0767]
# [nnest.trainer] [INFO] Epoch [400] train loss [0.0107] validation loss [0.0736]
# INFO:nnest.trainer:Epoch [400] train loss [0.0107] validation loss [0.0736]
# [nnest.trainer] [INFO] Epoch [450] train loss [0.0107] validation loss [0.0749]
# INFO:nnest.trainer:Epoch [450] train loss [0.0107] validation loss [0.0749]
# [nnest.trainer] [INFO] Epoch [455] ran out of patience
# INFO:nnest.trainer:Epoch [455] ran out of patience
# [nnest.trainer] [INFO] Best epoch [405] validation loss [0.0718]
# INFO:nnest.trainer:Best epoch [405] validation loss [0.0718]
# [nnest.sampler] [INFO] Step [200] acceptance [0.3520] min ESS [4.4025] max ESS [5.3271] average jump [0.3244]
# INFO:nnest.sampler:Step [200] acceptance [0.3520] min ESS [4.4025] max ESS [5.3271] average jump [0.3244]
# [nnest.sampler] [INFO] Step [400] acceptance [0.3460] min ESS [8.0411] max ESS [9.0150] average jump [0.3101]
# INFO:nnest.sampler:Step [400] acceptance [0.3460] min ESS [8.0411] max ESS [9.0150] average jump [0.3101]
# [nnest.sampler] [INFO] Step [600] acceptance [0.3433] min ESS [11.6658] max ESS [12.2833] average jump [0.3132]
# INFO:nnest.sampler:Step [600] acceptance [0.3433] min ESS [11.6658] max ESS [12.2833] average jump [0.3132]
# [nnest.sampler] [INFO] Step [800] acceptance [0.3508] min ESS [15.6756] max ESS [16.0387] average jump [0.3171]
# INFO:nnest.sampler:Step [800] acceptance [0.3508] min ESS [15.6756] max ESS [16.0387] average jump [0.3171]
# [nnest.sampler] [INFO] Step [1000] acceptance [0.3502] min ESS [20.0263] max ESS [20.6490] average jump [0.3247]
# INFO:nnest.sampler:Step [1000] acceptance [0.3502] min ESS [20.0263] max ESS [20.6490] average jump [0.3247]
# [nnest.sampler] [INFO] Step [1200] acceptance [0.3487] min ESS [21.3782] max ESS [24.7649] average jump [0.3219]
# INFO:nnest.sampler:Step [1200] acceptance [0.3487] min ESS [21.3782] max ESS [24.7649] average jump [0.3219]
# [nnest.sampler] [INFO] Step [1400] acceptance [0.3460] min ESS [25.3103] max ESS [29.9651] average jump [0.3242]
# INFO:nnest.sampler:Step [1400] acceptance [0.3460] min ESS [25.3103] max ESS [29.9651] average jump [0.3242]
# [nnest.sampler] [INFO] Step [1600] acceptance [0.3420] min ESS [27.9803] max ESS [30.5774] average jump [0.3246]
# INFO:nnest.sampler:Step [1600] acceptance [0.3420] min ESS [27.9803] max ESS [30.5774] average jump [0.3246]
# [nnest.sampler] [INFO] Step [1800] acceptance [0.3409] min ESS [31.3300] max ESS [33.9073] average jump [0.3246]
# INFO:nnest.sampler:Step [1800] acceptance [0.3409] min ESS [31.3300] max ESS [33.9073] average jump [0.3246]
# [nnest.sampler] [INFO] Step [2000] acceptance [0.3389] min ESS [33.0174] max ESS [37.1750] average jump [0.3209]
# INFO:nnest.sampler:Step [2000] acceptance [0.3389] min ESS [33.0174] max ESS [37.1750] average jump [0.3209]
# [nnest.sampler] [INFO] Step [2200] acceptance [0.3415] min ESS [37.3828] max ESS [41.4859] average jump [0.3243]
# INFO:nnest.sampler:Step [2200] acceptance [0.3415] min ESS [37.3828] max ESS [41.4859] average jump [0.3243]
# [nnest.sampler] [INFO] Step [2400] acceptance [0.3418] min ESS [41.0227] max ESS [45.3974] average jump [0.3229]
# INFO:nnest.sampler:Step [2400] acceptance [0.3418] min ESS [41.0227] max ESS [45.3974] average jump [0.3229]
# [nnest.sampler] [ERROR] Could not find inverse
# ERROR:nnest.sampler:Could not find inverse
# [nnest.sampler] [INFO] Step [2600] acceptance [0.3421] min ESS [44.9110] max ESS [50.3026] average jump [0.3266]
# INFO:nnest.sampler:Step [2600] acceptance [0.3421] min ESS [44.9110] max ESS [50.3026] average jump [0.3266]
# [nnest.sampler] [ERROR] Could not find inverse
# ERROR:nnest.sampler:Could not find inverse
# [nnest.sampler] [INFO] Step [2800] acceptance [0.3417] min ESS [46.1885] max ESS [54.8651] average jump [0.3250]
# INFO:nnest.sampler:Step [2800] acceptance [0.3417] min ESS [46.1885] max ESS [54.8651] average jump [0.3250]
# [nnest.sampler] [INFO] Step [3000] acceptance [0.3438] min ESS [50.8134] max ESS [58.6048] average jump [0.3295]
# INFO:nnest.sampler:Step [3000] acceptance [0.3438] min ESS [50.8134] max ESS [58.6048] average jump [0.3295]
# [nnest.sampler] [INFO] Step [3200] acceptance [0.3438] min ESS [54.0483] max ESS [63.0937] average jump [0.3280]
# INFO:nnest.sampler:Step [3200] acceptance [0.3438] min ESS [54.0483] max ESS [63.0937] average jump [0.3280]
# [nnest.sampler] [ERROR] Could not find inverse
# ERROR:nnest.sampler:Could not find inverse
# [nnest.sampler] [ERROR] Could not find inverse
# ERROR:nnest.sampler:Could not find inverse
# [nnest.sampler] [ERROR] Could not find inverse
# ERROR:nnest.sampler:Could not find inverse
# [nnest.sampler] [ERROR] Could not find inverse
# ERROR:nnest.sampler:Could not find inverse
# [nnest.sampler] [ERROR] Could not find inverse
# ERROR:nnest.sampler:Could not find inverse
# [nnest.sampler] [ERROR] Could not find inverse
# ERROR:nnest.sampler:Could not find inverse
# [nnest.sampler] [INFO] Step [3400] acceptance [0.3452] min ESS [57.4026] max ESS [63.4770] average jump [0.3264]
# INFO:nnest.sampler:Step [3400] acceptance [0.3452] min ESS [57.4026] max ESS [63.4770] average jump [0.3264]
# [nnest.sampler] [INFO] Step [3600] acceptance [0.3440] min ESS [60.3473] max ESS [68.0639] average jump [0.3259]
# INFO:nnest.sampler:Step [3600] acceptance [0.3440] min ESS [60.3473] max ESS [68.0639] average jump [0.3259]
# [nnest.sampler] [INFO] Step [3800] acceptance [0.3440] min ESS [65.4234] max ESS [70.0140] average jump [0.3265]
# INFO:nnest.sampler:Step [3800] acceptance [0.3440] min ESS [65.4234] max ESS [70.0140] average jump [0.3265]
# [nnest.sampler] [INFO] Step [4000] acceptance [0.3443] min ESS [68.9450] max ESS [74.5431] average jump [0.3281]
# INFO:nnest.sampler:Step [4000] acceptance [0.3443] min ESS [68.9450] max ESS [74.5431] average jump [0.3281]
# [nnest.sampler] [INFO] Step [4200] acceptance [0.3445] min ESS [70.2958] max ESS [78.1254] average jump [0.3281]
# INFO:nnest.sampler:Step [4200] acceptance [0.3445] min ESS [70.2958] max ESS [78.1254] average jump [0.3281]
# [nnest.sampler] [INFO] Step [4400] acceptance [0.3434] min ESS [73.8646] max ESS [78.3148] average jump [0.3280]
# INFO:nnest.sampler:Step [4400] acceptance [0.3434] min ESS [73.8646] max ESS [78.3148] average jump [0.3280]
# [nnest.sampler] [INFO] Step [4600] acceptance [0.3436] min ESS [78.9902] max ESS [83.7409] average jump [0.3285]
# INFO:nnest.sampler:Step [4600] acceptance [0.3436] min ESS [78.9902] max ESS [83.7409] average jump [0.3285]
# [nnest.sampler] [INFO] Step [4800] acceptance [0.3422] min ESS [81.1856] max ESS [88.4993] average jump [0.3268]
# INFO:nnest.sampler:Step [4800] acceptance [0.3422] min ESS [81.1856] max ESS [88.4993] average jump [0.3268]
# [nnest.sampler] [INFO] Step [5000] acceptance [0.3419] min ESS [85.2664] max ESS [91.4247] average jump [0.3261]
# INFO:nnest.sampler:Step [5000] acceptance [0.3419] min ESS [85.2664] max ESS [91.4247] average jump [0.3261]
# ncall: 14955

# %%
samples = [sampler.samples[i, :, :].squeeze() for i in range(sampler.samples.shape[0])]
latent_samples = [sampler.latent_samples[i, :, :].squeeze() for i in range(sampler.latent_samples.shape[0])]
loglikes = [-sampler.loglikes[i, :].squeeze() for i in range(sampler.loglikes.shape[0])]

# %%
mc = MCSamples(samples=samples, loglikes=loglikes)
# Out:
# Removed no burn in

# %%
print(mc.getEffectiveSamples())
print(mc.getMargeStats())
print(mc.getConvergeTests())
# Out:
# 668.6547312202829
# Marginalized limits: 0.68; 0.95; 0.99
#
# parameter   mean           sddev          lower1         upper1         limit1 lower2         upper2         limit2 lower3         upper3         limit3
# param1      9.1569762E-02  1.4308886E+00 -2.1022213E+00  2.1193986E+00  two   -2.0558773E+00  2.0738364E+00  two   -2.1424935E+00  2.1570498E+00  two     p_{1}
# param2     -1.9492324E-02  1.4180800E+00 -2.0738497E+00  2.1172055E+00  two   -2.0391545E+00  2.0681553E+00  two   -2.1154853E+00  2.1645998E+00  two     p_{2}
#
# Parameter autocorrelation lengths (effective number of samples N_eff = tot weight/weight length)
#
#             Weight Length   Sample length           N_eff
# param1           3.69E+01           36.89             676
# param2           4.07E+01           40.71             613
#
#
# mean convergence stats using remaining chains
# param sqrt(var(chain mean)/mean(chain var))
#
# param1        0.0585  p_{1}
# param2        0.0768  p_{2}
#
# var(mean)/mean(var) for eigenvalues of covariance of y of orthonormalized parameters
#   1      0.00341
#   2      0.00591
#
# Split tests: rms_n([delta(upper/lower quantile)]/sd) n={2,3,4}, limit=95%:
# i.e. mean sample splitting change in the quantiles in units of the st. dev.
#
# param1       0.0084   0.0080   0.0101 upper
# param1       0.0001   0.0061   0.0044 lower
# param2       0.0076   0.0073   0.0091 upper
# param2       0.0035   0.0076   0.0088 lower
#
# Raftery&Lewis statistics
#
# chain  markov_thin  indep_thin    nburn
#    0           1          18          44
#    1           1           8          35
#    2           1          14          49
#    3           1          13          50
#    4           1          15          44

# %%
g = plots.getSubplotPlotter(width_inch=8)
g.triangle_plot(mc, filled=True)

# %%
fig, ax = plt.subplots(1, 2, figsize=(12,6))
ax[0].plot(samples[0][2000:2500,0], samples[0][2000:2500,1])
ax[1].plot(latent_samples[0][500:1000,0], latent_samples[0][500:1000,1])
plt.show()

# %%
fig, ax = plt.subplots(like.x_dim, 1, figsize=(10, like.x_dim))
for i in range(like.x_dim):
    ax[i].plot(samples[0][500:1500,i])
plt.show()

# %%
like.num_evaluations
# Out:
# 16221
